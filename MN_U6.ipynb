# %% [markdown]
# <a href="https://colab.research.google.com/github/laxhidualopez06/Py---1--Laxhidua/blob/main/MN_U6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1 - Resolver una EDO simple**

# %%
import numpy as np

def f(x,y): #Define la  ecuacion diferencial
  return x + y #Retorna el valor de dy/dx

x = 0 #Valor inicial de x
y = 1 #Condicion inicial y(0)=1

h = 0.1 #tamaño del paso

for i in range(5): #Ejecuta 5 iteraciones
  y = y + h*f(x,y) #aproximacion numerica tipo euler
  x = x + h #Avanza al siguiente punto

  print("x = ",x,"y = ",y) #Muestra resultados
# Out:
# x =  0.1 y =  1.1
# x =  0.2 y =  1.2200000000000002
# x =  0.30000000000000004 y =  1.362
# x =  0.4 y =  1.5282
# x =  0.5 y =  1.72102

# %% [markdown]
# # **Ejercicio 2 - Visualización de la solución**

# %%
import matplotlib.pyplot as plt

def f(x,y): #Define la ecuacion diferencial
  return x + y #retorna pendiente

x = 0 #Valor inicial
y = 1 #Condicion inicial

h = 0.1 #Paso numerico

x_vals = [] #lista para almacenar valores de x
y_vals = [] #Lista para almacenar valores en y

for i in range(20): #Ejecuta 20 pasos
  x_vals.append(x) #guarda valor actual de x
  y_vals.append(y) #Guarda valor actual de y

  y = y + h * f(x,y) #Metodo de euler
  x = x + h #Incrementa en x

plt.plot(x_vals,y_vals) #Grafica la solucion aproximada
plt.xlabel("x") #Etiqueta eje x
plt.ylabel("y") #Etiqueta eje y
plt.title("Solucion aproximada de la EDO") #Titulo
plt.grid() #Activa cuadricula
plt.show() #Muestra grafica

# %% [markdown]
# # **Ejercicio 3 - Aplicación IA : dinámica de aprendizaje**

# %%
import numpy as np

def f(t,w): #Define ecuacion diferencial
  return -0.5*w #Modelo de decaimento exponencial

t = 0 #Tiempo inicial

w = 10 #Paso inicial del modelo

h = 0.1 #Paso temporal

for i in range(20): #Ejecuta 20 iteraciones
  w = w + h*f(t,w) #Actualiza el peso
  t = t + h #Incrementa tiempo

  print("t = ",t,"w = ",w) #Muestra evolucion
# Out:
# t =  0.1 w =  9.5
# t =  0.2 w =  9.025
# t =  0.30000000000000004 w =  8.57375
# t =  0.4 w =  8.1450625
# t =  0.5 w =  7.737809374999999
# t =  0.6 w =  7.3509189062499996
# t =  0.7 w =  6.9833729609374995
# t =  0.7999999999999999 w =  6.634204312890624
# t =  0.8999999999999999 w =  6.302494097246093
# t =  0.9999999999999999 w =  5.987369392383789
# t =  1.0999999999999999 w =  5.6880009227646
# t =  1.2 w =  5.40360087662637
# t =  1.3 w =  5.133420832795051
# t =  1.4000000000000001 w =  4.876749791155298
# t =  1.5000000000000002 w =  4.632912301597533
# t =  1.6000000000000003 w =  4.401266686517657
# t =  1.7000000000000004 w =  4.1812033521917735
# t =  1.8000000000000005 w =  3.972143184582185
# t =  1.9000000000000006 w =  3.7735360253530756
# t =  2.0000000000000004 w =  3.584859224085422

# %% [markdown]
# # **Ejercicio 1 - Implementación básica de Euler**

# %%
def f(x,y): #Define la ecuacion diferencial
  return x + y #retorna pendiente

x = 0 #Valor inicial
y = 1 #Condicion inicial

h = 0.1 #Paso numerico

n = 10 #Numero de iteraciones

for i in range(n): #Ejecuta n iteraciones
  y = y + h*f(x,y) #aproximacion numerica tipo euler
  x = x + h #Avanza al siguiente punto

  print("x = ",x,"y = ",y) #Muestra resultados
# Out:
# x =  0.1 y =  1.1
# x =  0.2 y =  1.2200000000000002
# x =  0.30000000000000004 y =  1.362
# x =  0.4 y =  1.5282
# x =  0.5 y =  1.72102
# x =  0.6 y =  1.943122
# x =  0.7 y =  2.1974342
# x =  0.7999999999999999 y =  2.48717762
# x =  0.8999999999999999 y =  2.8158953820000003
# x =  0.9999999999999999 y =  3.1874849202

# %% [markdown]
# # **Ejercicio 2 - Comparación con solución exacta**

# %%
def f(x,y): #Define la ecuacion diferencial
  return x + y #retorna pendiente

def exacta(x): #Define la solucion analitica
  return 2*np.exp(x)-x-1 #formula exacta

x = 0 #Valor inicial
y = 1 #Condicion inicial

h = 0.1 #Paso numerico

for i in range(10): #Ejecuta 10 iteraciones
  y = y + h*f(x,y) #aproximacion numerica tipo euler
  x = x + h #Avanza al siguiente punto

  real = exacta(x) #Solucion exacta

  error = abs(real-y) #Calcula error absoluto

  print("x = ",x,"euler = ",y , "exacta = ",real, "Error: ",error) #Muestra resultados
# Out:
# x =  0.1 euler =  1.1 exacta =  1.1103418361512953 Error:  0.010341836151295247
# x =  0.2 euler =  1.2200000000000002 exacta =  1.2428055163203395 Error:  0.022805516320339336
# x =  0.30000000000000004 euler =  1.362 exacta =  1.3997176151520065 Error:  0.037717615152006445
# x =  0.4 euler =  1.5282 exacta =  1.5836493952825408 Error:  0.05544939528254078
# x =  0.5 euler =  1.72102 exacta =  1.7974425414002564 Error:  0.0764225414002564
# x =  0.6 euler =  1.943122 exacta =  2.0442376007810177 Error:  0.10111560078101767
# x =  0.7 euler =  2.1974342 exacta =  2.327505414940953 Error:  0.13007121494095308
# x =  0.7999999999999999 euler =  2.48717762 exacta =  2.651081856984935 Error:  0.16390423698493484
# x =  0.8999999999999999 euler =  2.8158953820000003 exacta =  3.0192062223138993 Error:  0.203310840313899
# x =  0.9999999999999999 euler =  3.1874849202 exacta =  3.43656365691809 Error:  0.24907873671809

# %% [markdown]
# # **Ejercicio 3 - Aplicación IA : descenso dinámico**

# %%
def f(t,w): #Define la ecuacion diferencial
  return -0.3*w #Modelo del decaimento del peso

t = 0 #Valor inicial
w = 5 #Condicion inicial

h = 0.2 #Paso numerico

n = 20 #Numero de iteraciones

for i in range(n): #Ejecuta n iteraciones
  w = w + h*f(t,w) #aproximacion numerica tipo euler
  t = t + h #Avanza al siguiente punto

  print("t = ",t,"w = ",w) #Muestra resultados
# Out:
# t =  0.2 w =  4.7
# t =  0.4 w =  4.418
# t =  0.6000000000000001 w =  4.15292
# t =  0.8 w =  3.9037448
# t =  1.0 w =  3.6695201120000003
# t =  1.2 w =  3.4493489052800004
# t =  1.4 w =  3.2423879709632004
# t =  1.5999999999999999 w =  3.0478446927054086
# t =  1.7999999999999998 w =  2.864974011143084
# t =  1.9999999999999998 w =  2.693075570474499
# t =  2.1999999999999997 w =  2.5314910362460292
# t =  2.4 w =  2.3796015740712675
# t =  2.6 w =  2.2368254796269915
# t =  2.8000000000000003 w =  2.102615950849372
# t =  3.0000000000000004 w =  1.9764589937984094
# t =  3.2000000000000006 w =  1.8578714541705048
# t =  3.400000000000001 w =  1.7463991669202745
# t =  3.600000000000001 w =  1.641615216905058
# t =  3.800000000000001 w =  1.5431183038907546
# t =  4.000000000000001 w =  1.4505312056573092

# %% [markdown]
# # **Ejercicio 4 - Visualización gráfica**

# %%
import matplotlib.pyplot as plt

def f(x,y): #Define la ecuacion diferencial
  return x + y #retorna pendiente

x = 0 #Valor inicial
y = 1 #Condicion inicial

h = 0.1 #Paso numerico

x_vals = [] #lista para almacenar valores de x
y_vals = [] #Lista para almacenar valores en y

for i in range(20): #Ejecuta 20 pasos
  x_vals.append(x) #guarda valor actual de x
  y_vals.append(y) #Guarda valor actual de y

  y = y + h * f(x,y) #Metodo de euler
  x = x + h #Incrementa en x

plt.plot(x_vals,y_vals) #Grafica la solucion aproximada
plt.xlabel("x") #Etiqueta eje x
plt.ylabel("y") #Etiqueta eje y
plt.title("Solucion aproximada de la EDO") #Titulo
plt.grid() #Activa cuadricula
plt.show() #Muestra grafica

# %% [markdown]
# # **Ejercicio 1 - Método RK2**

# %%
import numpy as np

def f(x,y): #Define la  ecuacion diferencial
  return x + y #Retorna el valor de dy/dx

x = 0 #Valor inicial de x
y = 1 #Condicion inicial y(0)=1

h = 0.1 #tamaño del paso

n = 10

for i in range(n): #Ejecuta el metodo rk2
  k1 = f(x,y) #Calcula primer pendiente
  k2 = f(x + h/2 , y + h*k1/2) #Calcula segunda pendiente
  y = y + h*k2 #aproximacion numerica tipo euler
  x = x + h #Avanza al siguiente punto

  print("x = ",x,"y = ",y) #Muestra resultados
# Out:
# x =  0.1 y =  1.11
# x =  0.2 y =  1.24205
# x =  0.30000000000000004 y =  1.39846525
# x =  0.4 y =  1.5818041012500001
# x =  0.5 y =  1.7948935318812502
# x =  0.6 y =  2.0408573527287817
# x =  0.7 y =  2.3231473747653038
# x =  0.7999999999999999 y =  2.6455778491156607
# x =  0.8999999999999999 y =  3.012363523272805
# x =  0.9999999999999999 y =  3.42816169321645

# %% [markdown]
# # **Ejercicio 2 - RK4**

# %%
import numpy as np

def f(x,y): #Define la  ecuacion diferencial
  return x + y #Retorna el valor de dy/dx

x = 0 #Valor inicial de x
y = 1 #Condicion inicial y(0)=1

h = 0.1 #tamaño del paso

n = 10 #Numero de iteraciones

for i in range(n): #Ejecuta el metodo rk2
  k1 = f(x,y) #Calcula primer pendiente
  k2 = f(x + h/2 , y + h*k1/2) #Calcula segunda pendiente
  k3 = f(x + h/2 , y + h*k2/2) #Calcula tercer pendiente
  k4 = f(x + h , y + h*k3) #Calcula cuarta pendiente
  y = y + h*k2 #aproximacion numerica tipo euler
  x = x + h #Avanza al siguiente punto

  print("x = ",x,"y = ",y) #Muestra resultados
# Out:
# x =  0.1 y =  1.11
# x =  0.2 y =  1.24205
# x =  0.30000000000000004 y =  1.39846525
# x =  0.4 y =  1.5818041012500001
# x =  0.5 y =  1.7948935318812502
# x =  0.6 y =  2.0408573527287817
# x =  0.7 y =  2.3231473747653038
# x =  0.7999999999999999 y =  2.6455778491156607
# x =  0.8999999999999999 y =  3.012363523272805
# x =  0.9999999999999999 y =  3.42816169321645

# %% [markdown]
# # **Ejercicio 3 - Comparación Euler vs Rk4**

# %%
def f(x,y): #Define la ecuacion diferencial
  return x + y #retorna pendiente

def exacta(x): #Define la solucion analitica
  return 2*np.exp(x)-x-1 #formula exacta

x = 0 #Valor inicial

h = 0.1 #Paso numerico

y_euler = 1 #Condicion inicial para euler

y_rk4 = 1 #condicion inicial para rk4

for i in range(10):

  #Metodo de euler
  y_euler = y_euler + h*f(x,y_euler) #aproximacion numerica tipo euler

  #Metodo RK4
  k1 = f(x,y) #Calcula primer pendiente
  k2 = f(x + h/2 , y + h*k1/2) #Calcula segunda pendiente
  k3 = f(x + h/2 , y + h*k2/2) #Calcula tercer pendiente
  k4 = f(x + h , y + h*k3) #Calcula cuarta pendiente

  y_rk4 = y_rk4 + (h/6)*(k1 + 2*k2 + 2*k3 + k4) #Actualiza rk4

  x = x+h

  real = exacta(x) #Calcula la solucion exacta

  error_euler = abs(real-y_euler) #Error euler
  error_rk4 = abs(real-y_rk4) #Error rk4

  print("Exacta: ",real)
  print("Euler: ",y_euler)
  print("RK4: ",y_rk4)
  print("Error euler: ",error_euler)
  print("Error RK4: ",error_rk4)
# Out:
# Exacta:  1.1103418361512953
# Euler:  1.1
# RK4:  1.3657134554103183
# Error euler:  0.010341836151295247
# Error RK4:  0.25537161925902296
# Exacta:  1.2428055163203395
# Euler:  1.2200000000000002
# RK4:  1.74194399415397
# Error euler:  0.022805516320339336
# Error RK4:  0.4991384778336305
# Exacta:  1.3997176151520065
# Euler:  1.362
# RK4:  2.128691616230955
# Error euler:  0.037717615152006445
# Error RK4:  0.7289740010789485
# Exacta:  1.5836493952825408
# Euler:  1.5282
# RK4:  2.5259563216412735
# Error euler:  0.05544939528254078
# Error RK4:  0.9423069263587327
# Exacta:  1.7974425414002564
# Euler:  1.72102
# RK4:  2.933738110384925
# Error euler:  0.0764225414002564
# Error RK4:  1.1362955689846688
# Exacta:  2.0442376007810177
# Euler:  1.943122
# RK4:  3.35203698246191
# Error euler:  0.10111560078101767
# Error RK4:  1.3077993816808924
# Exacta:  2.327505414940953
# Euler:  2.1974342
# RK4:  3.780852937872228
# Error euler:  0.13007121494095308
# ...

# %% [markdown]
# # **Ejercicio 4 - Aplicación IA : dinámica pesos**

# %%
def f(t,w): #Define la ecuacion diferencial
  return -0.3*w #Modelo del decaimento del peso

t = 0 #Valor inicial
w = 10 #Condicion inicial

h = 0.1 #Paso numerico

for i in range(n): #Ejecuta el metodo rk2
  k1 = f(x,y) #Calcula primer pendiente
  k2 = f(x + h/2 , y + h*k1/2) #Calcula segunda pendiente
  k3 = f(x + h/2 , y + h*k2/2) #Calcula tercer pendiente
  k4 = f(x + h , y + h*k3) #Calcula cuarta pendiente

  w = w + (h/6)*(k1 + 2*k2 + 2*k3 + k4) #Actualiza rk4

  t = t + h #Incrementa tiempo

  print("t =",t,"w =",w) #Muestra evolucion
# Out:
# t = 0.1 w = 9.898682510938292
# t = 0.2 w = 9.797365021876583
# t = 0.30000000000000004 w = 9.696047532814875
# t = 0.4 w = 9.594730043753167
# t = 0.5 w = 9.493412554691458
# t = 0.6 w = 9.39209506562975
# t = 0.7 w = 9.290777576568042
# t = 0.7999999999999999 w = 9.189460087506333
# t = 0.8999999999999999 w = 9.088142598444625
# t = 0.9999999999999999 w = 8.986825109382917
